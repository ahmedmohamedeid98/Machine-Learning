# %% [markdown]
# <h3>Here we will show some ways to Distribution the <b>data</b></h3><br>
# <h5>1.UNIFORM DISTRIBUTION</h5><br>
# <h5>2.NORMAL/GAUSSIAN DISTRIBUTION [PDF]</h5><br>
# <h5>3.EPONENTIAL PDF DISTRIBUTION</h5><br>
# <h5>4.BINOMAIL DISTRIBUTION [PMF]</h5><br>
# <h5>5.POISSON DISTRIBUTION [PMF]</h5><br>

# %% [markdown]
# # 1.Uniform Distribution

# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.random.uniform(-10,10,100000)
plt.hist(x , 50)
plt.show()

# %% [markdown]
# # 2.Normal / Gaussain Distribution [pdf]

# %%
import numpy as np 
from scipy.stats import norm
import matplotlib.pyplot as plt

x = np.arange(-3,3,0.001)
plt.plot(x, norm.pdf(x))

# %% [markdown]
# <h5>Using Mu as mean and segma as std to show normal distribution</h5>

# %%
mu = 50
segma = 8
x = np.random.normal(mu, segma, 10000)
plt.hist(x, 50)
plt.show()

# %% [markdown]
# # 3.Eponential Distribution [pdf]

# %%
import numpy as np 
from scipy.stats import expon
import matplotlib.pyplot as plt

x = np.arange(0,10,0.001)
plt.plot(x , expon.pdf(x))
plt.show()

# %% [markdown]
# # 4.Binomial [pmf]

# %%
import numpy as np 
from scipy.stats import binom
import matplotlib.pyplot as plt

n = 10
p = 0.5
x = np.arange(0,10,0.001)
plt.plot(x, binom.pmf(x, n, p))
plt.show()

# %% [markdown]
# # 5.Poisson [pmf]

# %%
import numpy as np 
from scipy.stats import poisson
import matplotlib.pyplot as plt
from matplotlib.pyplot import style
style.use("fivethirtyeight")
mu = 500
x = np.arange(400,600,0.5)

plt.plot(x , poisson.pmf(x, mu))
plt.show()
